# %%
churn_fulldf = {
    # INSERT IN ORDER: [accuracy, macro, weighted]
    'Logistic Regression':  [0.74, 0.70, 0.75],
    'Random Forest': [0.76, 0.72, 0.77],
    'XGBoost': [ 0.75, 0.71 , 0.76],
    'kNN': [0.71, 0.67, 0.72],
    'MLP': [0.70, 0.67, 0.71]
}

churn_random = {
    # INSERT IN ORDER: [accuracy, macro, weighted]
    'Logistic Regression':  [0.70, 0.68, 0.72],
    'Random Forest': [0.73, 0.69, 0.74],
    'XGBoost': [0.73, 0.68, 0.74],
    'kNN': [0.70, 0.65, 0.71],
    'MLP': [0.65, 0.64, 0.67],
}

churn_shap = {
    # INSERT IN ORDER: [accuracy, macro, weighted]
    'Logistic Regression':  [0.71, 0.67, 0.72],
    'Random Forest': [0.73, 0.69, 0.74],
    'XGBoost': [0.71, 0.68, 0.73],
    'kNN': [0.75, 0.68, 0.75],
    'MLP': [0.74, 0.69, 0.75],
}

churn_brouta = {
    # INSERT IN ORDER: [accuracy, macro, weighted]
    'Logistic Regression':  [0.72 , 0.69 , 0.73],
    'Random Forest': [ 0.73, 0.70, 0.74],
    'XGBoost': [ 0.73,0.70 ,0.74 ],
    'kNN': [0.70 , 0.66, 0.71 ],
    'MLP': [0.70 ,0.70 ,0.76 ],
}

# %%
import matplotlib.pyplot as plt 
import numpy as np

labels = churn_fulldf.keys()

churn_fulldf_accuracy = [v[0] for v in churn_fulldf.values()]
churn_shap_accuracy   = [v[0] for v in churn_shap.values()]
churn_brouta_accuracy = [v[0] for v in churn_brouta.values()]
churn_random_accuracy = [v[0] for v in churn_random.values()]

churn_fulldf_macro = [v[1] for v in churn_fulldf.values()]
churn_shap_macro   = [v[1] for v in churn_shap.values()]
churn_brouta_macro = [v[1] for v in churn_brouta.values()]
churn_random_macro = [v[1] for v in churn_random.values()]

churn_fulldf_weighted = [v[2] for v in churn_fulldf.values()]
churn_shap_weighted   = [v[2] for v in churn_shap.values()]
churn_brouta_weighted = [v[2] for v in churn_brouta.values()]
churn_random_weighted = [v[2] for v in churn_random.values()]

x = np.arange(len(labels))
width = 0.2

fig, ax = plt.subplots(figsize=(8, 5))
rects1 = ax.bar(x - width, churn_fulldf_accuracy, width, label='Full Data')
rects2 = ax.bar(x, churn_shap_accuracy, width, label='Shap-Subset')
rects3 = ax.bar(x + width, churn_brouta_accuracy, width, label='Brouta-Subset')
rects4 = ax.bar(x + 2 * width, churn_random_accuracy, width, label='Random Forest-Subset')

ax.set_ylabel('Accuracy')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.4))

fig.tight_layout()
fig.savefig('figures/churn_accuracy.png')

# %%
fig, ax = plt.subplots(figsize=(8, 5))
rects1 = ax.bar(x - width, churn_fulldf_macro, width, label='Full Data')
rects2 = ax.bar(x, churn_shap_macro, width, label='Shap-Subset')
rects3 = ax.bar(x + width, churn_brouta_macro, width, label='Brouta-Subset')
rects4 = ax.bar(x + 2 * width, churn_random_macro, width, label='Random Forest-Subset')

ax.set_ylabel('Macro F1')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.4))

fig.tight_layout()
fig.savefig('figures/churn_macro_f1.png')

# %%
fig, ax = plt.subplots(figsize=(8, 5))
rects1 = ax.bar(x - width, churn_fulldf_weighted, width, label='Full Data')
rects2 = ax.bar(x, churn_shap_weighted, width, label='Shap-Subset')
rects3 = ax.bar(x + width, churn_brouta_weighted, width, label='Brouta-Subset')
rects4 = ax.bar(x + 2 * width, churn_random_weighted, width, label='Random Forest-Subset')

ax.set_ylabel('Weighted F1')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.4))

fig.tight_layout()
fig.savefig('figures/churn_weighted_f1.png')

# %% [markdown]
# ## Random Search

# %%
churn_fulldf_no_hp = {
    # INSERT IN ORDER: [accuracy, macro, weighted]
    'Logistic Regression':  [0.74, 0.70, 0.75],
    'Random Forest': [0.76, 0.69, 0.76],
    'XGBoost': [ 0.71,0.77 , 0.77],
    'kNN': [0.69, 0.66, 0.71],
    'MLP': [0.77,0.71 ,0.77 ]
}

# %%
labels = churn_fulldf.keys()

churn_fulldf_accuracy = [v[0] for v in churn_fulldf.values()]
churn_fulldf_no_hp_accuracy   = [v[0] for v in churn_fulldf_no_hp.values()]

churn_fulldf_macro = [v[1] for v in churn_fulldf.values()]
churn_fulldf_no_hp_macro = [v[1] for v in churn_fulldf_no_hp.values()]

churn_fulldf_weighted = [v[2] for v in churn_fulldf.values()]
churn_fulldf_no_hp_weighted = [v[2] for v in churn_fulldf_no_hp.values()]

x = np.arange(len(labels))
width = 0.2

fig, ax = plt.subplots(figsize=(8, 5))
rects1 = ax.bar(x - width, churn_fulldf_accuracy, width, label='Random Search-Optimized')
rects2 = ax.bar(x, churn_fulldf_no_hp_accuracy, width, label='Original (No Optimization)')

ax.set_ylabel('Accuracy')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.4))

fig.tight_layout()
fig.savefig('figures/churn_random_search_accuracy.png')

# %%
fig, ax = plt.subplots(figsize=(8, 5))
rects1 = ax.bar(x - width, churn_fulldf_macro, width, label='Random Search-Optimized')
rects2 = ax.bar(x, churn_fulldf_no_hp_macro, width, label='Original (No Optimization)')

ax.set_ylabel('Macro F1')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.4))

fig.tight_layout()
fig.savefig('figures/churn_random_search_macro_f1.png')

# %%
fig, ax = plt.subplots(figsize=(8, 5))
rects1 = ax.bar(x - width, churn_fulldf_weighted, width, label='Random Search-Optimized')
rects2 = ax.bar(x, churn_fulldf_no_hp_weighted, width, label='Original (No Optimization)')

ax.set_ylabel('Weighted F1')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.4))

fig.tight_layout()
fig.savefig('figures/churn_random_search_weighted_f1.png')

# %%
engineering_fulldf = {
    # INSERT IN ORDER: [MSE, RMSE, R2, Explained Variance]
    'Regression': [38.25 ,6.19 ,0.63 ,0.66 ],
    'Random Forest': [ 21.43,4.63 , 0.78, 0.80],
    'Elastic Net': [ 38.82, 6.23, 0.62,0.65 ],
    'Ridge': [72.57 , 8.52, 0.23, 0.33],
    'Lasso': [ 5.83,5.98 ,0.65 ,0.68 ],
    'XGBoost': [35.4, 5.93, 0.66, 0.68],
    'MLP': [248.79, 15.77, 0.0, 0.0]
}

engineering_fulldf_no_hp = {
    # INSERT IN ORDER: [MSE, RMSE, R2, Explained Variance]
    'Regression': [38.25 ,6.19 ,0.63 ,0.66 ],
    'Random Forest': [ 21.43,4.63 , 0.78, 0.80],
    'Elastic Net': [ 63.43, 7.96, 0.39,0.42 ],
    'Ridge': [72.57 , 8.52, 0.23, 0.33],
    'Lasso': [46.61, 6.83 ,0.55 ,0.58 ],
    'XGBoost': [35.13, 5.93, 0.66, 0.68],
    'MLP': [248.79, 15.77, 0.0, 0.0]
}

# %%
labels = engineering_fulldf.keys()

engineering_fulldf_mse = [v[0] for v in engineering_fulldf.values()]
engineering_fulldf_no_hp_mse  = [v[0] for v in engineering_fulldf_no_hp.values()]

engineering_fulldf_rmse = [v[1] for v in engineering_fulldf.values()]
engineering_fulldf_no_hp_rmse  = [v[1] for v in engineering_fulldf_no_hp.values()]

engineering_fulldf_r2 = [v[2] for v in engineering_fulldf.values()]
engineering_fulldf_no_hp_r2 = [v[2] for v in engineering_fulldf_no_hp.values()]

engineering_fulldf_ev = [v[3] for v in engineering_fulldf.values()]
engineering_fulldf_no_hp_ev = [v[3] for v in engineering_fulldf_no_hp.values()]

x = np.arange(len(labels))
width = 0.2

fig, ax = plt.subplots(figsize=(8, 5))
rects1 = ax.bar(x - width, engineering_fulldf_mse, width, label='Random Search-Optimized')
rects2 = ax.bar(x, engineering_fulldf_no_hp_mse, width, label='Original (No Optimization)')

ax.set_ylabel('MSE')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.4))

fig.tight_layout()
fig.savefig('figures/engineering_random_search_mse.png')

# %%
fig, ax = plt.subplots(figsize=(8, 5))
rects1 = ax.bar(x - width, engineering_fulldf_rmse, width, label='Random Search-Optimized')
rects2 = ax.bar(x, engineering_fulldf_no_hp_rmse, width, label='Original (No Optimization)')

ax.set_ylabel('RMSE')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.4))

fig.tight_layout()
fig.savefig('figures/engineering_random_search_rmse.png')

# %%
fig, ax = plt.subplots(figsize=(8, 5))
rects1 = ax.bar(x - width, engineering_fulldf_r2, width, label='Random Search-Optimized')
rects2 = ax.bar(x, engineering_fulldf_no_hp_r2, width, label='Original (No Optimization)')

ax.set_ylabel('R2')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.4))

fig.tight_layout()
fig.savefig('figures/engineering_random_search_r2.png')

# %%
fig, ax = plt.subplots(figsize=(8, 5))
rects1 = ax.bar(x - width, engineering_fulldf_r2, width, label='Random Search-Optimized')
rects2 = ax.bar(x, engineering_fulldf_no_hp_r2, width, label='Original (No Optimization)')

ax.set_ylabel('Explained Variance')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.4))

fig.tight_layout()
fig.savefig('figures/engineering_random_search_explained.png')
